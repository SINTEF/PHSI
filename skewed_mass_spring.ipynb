# %% [markdown]
# Training the PHSI model on a skewed mass-spring system with damping and external force. The goal is to see how the pruning hyperparameters affect the pruning and the learning of terms with small coefficients.

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
#import from phlearn
from phlearn.phnns import PseudoHamiltonianNN
from phlearn.phnns import R_estimator, HamiltonianNN, ExternalForcesNN
from phlearn.phnns import npoints_to_ntrajectories_tsample

#import from phsi
from phsi.phsystems import init_smsdsystem
from phsi.phnns import PHSI, ExternalForcesSI, BaselineSI, generate_dataset, train
ttype = torch.float32
torch.set_default_dtype(ttype)

# %%
#set up parameters
ntrainingpoints = 5000
sampling_time = 1/10
t_max = 10
integrator = 'srk4'
F_timedependent = True
F_statedependent = False
hidden_dim = 100
learning_rate = 5e-3
batch_size = 32
epochs = 150
l1_param_forces = 0.01
l1_param_dissipation = 0.
l1_val_params = 0.1
pruning_interval = 20
pruning_epsilon = 5e-2
shuffle = True
noise_std = 0.
seed = 1
verbose = True
ntrajectories_val = 0

# %%
print('Set up skewed mass-spring system')
ntrajectories_train, t_sample = npoints_to_ntrajectories_tsample(ntrainingpoints, t_max, sampling_time)

gamma = 0.07 # gamma
print('skewed parameter:', gamma)
pH_system = init_smsdsystem(skewed=gamma)
pH_system.seed(seed=seed)
damped_states = [False, True]

nstates = pH_system.nstates

# %%
#generate data
traindata = generate_dataset(pH_system, integrator, ntrajectories_train, t_sample, nsamples=ntrainingpoints, noise_std=noise_std)
valdata = generate_dataset(pH_system, integrator, ntrajectories_val, t_sample, noise_std=noise_std)

#generate noisy data
noise_std = 0.2
print('noise_std:', noise_std)
traindata_noise = generate_dataset(pH_system, integrator, ntrajectories_train, t_sample, nsamples=ntrainingpoints, noise_std=noise_std)
valdata_noise = generate_dataset(pH_system, integrator, ntrajectories_val, t_sample, noise_std=noise_std)

# %%
#set up PHSI model
function_space_ext = np.array([1,1])
external_forces_filter = np.zeros(nstates)
external_forces_filter[-1] = 1
ext_forces_si = ExternalForcesSI(nstates, F_timedependent, F_statedependent, \
                                function_space_ext, degrees=3)
ext_forces_si_noise = ExternalForcesSI(nstates, F_timedependent, F_statedependent, \
                                function_space_ext, degrees=3)

r_estimator = R_estimator(damped_states)
r_estimator_noise = R_estimator(damped_states)
function_space = np.array([1,0])
model_phsi=PHSI(nstates, pH_system.structure_matrix, function_space, \
                ext_forces_si, r_estimator, degrees=3, full_si=True)
model_phsi_noise=PHSI(nstates, pH_system.structure_matrix, function_space, \
                ext_forces_si_noise, r_estimator_noise, degrees=3, full_si=True)

optimizer_phsi = torch.optim.Adam(model_phsi.parameters(), lr=learning_rate, weight_decay=1e-4)
optimizer_phsi_noise = torch.optim.Adam(model_phsi_noise.parameters(), lr=learning_rate, weight_decay=1e-4)

# %%
print('Train PHSI model')
phsi, vloss_phsi = train(model_phsi, integrator, traindata, optimizer_phsi, valdata=valdata, epochs=epochs,
                  batch_size=batch_size, shuffle=shuffle, l1_param_forces=l1_param_forces,
                  l1_param_dissipation=l1_param_dissipation, l1_val_params=l1_val_params, prune_val=pruning_interval, prune_eps=pruning_epsilon,
                  loss_fn=torch.nn.MSELoss(), verbose=verbose, return_best=True)

# %%
print('Train PHSI model on noisy data')
phsi_noise, vloss_phsi = train(model_phsi_noise, integrator, traindata_noise, optimizer_phsi_noise, valdata=valdata, epochs=epochs,
                  batch_size=batch_size, shuffle=shuffle, l1_param_forces=l1_param_forces,
                  l1_param_dissipation=l1_param_dissipation, l1_val_params=l1_val_params, prune_val=pruning_interval, prune_eps=pruning_epsilon,
                  loss_fn=torch.nn.MSELoss(), verbose=verbose, return_best=True)

# %% [markdown]
# The exact results depend on the random parameters in the stochastic Adam optimizer. We give here more details on the results reported in our paper, achieved with different choices of `gamma` and `pruning_epsilon`.

# %% [raw]
# ## With pruning_epsilon=5e-2
#
# Set up skewed mass-spring system
# skewed parameter: 0.07
# noise_std: 0.2
#
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.5e-03
# x^[2 0]: 0.4983, x^[1 1]: 0.0718, x^[0 2]: 0.5006,
# r1:  0.2983,
# Forces Parameters:
# sin(x_0): amp= 1.9821 freq= 0.4991
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.05e+00
# x^[2 0]: 0.4968, x^[0 2]: 0.5034,
# r1:  0.3507,
# Forces Parameters:
# sin(x_0): amp= 1.9402 freq= 0.5208
#
# Set up skewed mass-spring system
# skewed parameter: 0.03
# noise_std: 0.2
#
# Train PHSI model
# Finished training after epoch 149
# Training loss: 9.09e-03
# x^[2 0]: 0.5027, x^[0 2]: 0.4954,
# r1:  0.3291,
# Forces Parameters:
# sin(x_0): amp= 1.9821 freq= 0.4998
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.02e+00
# x^[2 0]: 0.4900, x^[0 2]: 0.4825,
# r1:  0.3314,
# Forces Parameters:
# sin(x_0): amp= 1.9483 freq= 0.4819
#
# Set up skewed mass-spring system
# skewed parameter: 0.007
# noise_std: 0.2
#
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.66e-03
# x^[2 0]: 0.4984, x^[0 2]: 0.4988,
# r1:  0.3046,
# Forces Parameters:
# sin(x_0): amp= 1.9793 freq= 0.4992
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.02e+00
# x^[2 0]: 0.4930, x^[0 2]: 0.5293,
# r1:  0.3152,
# Forces Parameters:
# sin(x_0): amp= 1.9494 freq= 0.4998
#
# Set up skewed mass-spring system
# skewed parameter: 0.003
# noise_std: 0.2
#
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.54e-03
# x^[2 0]: 0.4986, x^[0 2]: 0.5000,
# r1:  0.3009,
# Forces Parameters:
# sin(x_0): amp= 1.9838 freq= 0.5001
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.02e+00
# x^[2 0]: 0.4670, x^[0 2]: 0.4773,
# r1:  0.2943,
# Forces Parameters:
# sin(x_0): amp= 1.9556 freq= 0.5023
#
# Set up skewed mass-spring system
# skewed parameter: 0.0003
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.50e-03
# x^[2 0]: 0.4986, x^[0 2]: 0.5001,
# r1:  0.2977,
# Forces Parameters:
# sin(x_0): amp= 1.9819 freq= 0.5007
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.02e+00
# x^[2 0]: 0.5022, x^[0 2]: 0.5275,
# r1:  0.2994,
# Forces Parameters:
# sin(x_0): amp= 1.9420 freq= 0.5078
#
# Set up skewed mass-spring system
# skewed parameter: 0.0007
# noise_std: 0.2
# Finished training after epoch 149
# Training loss: 8.04e+00
# x^[2 0]: 0.5030, x^[0 2]: 0.5201,
# r1:  0.2903,
# Forces Parameters:
# sin(x_0): amp= 1.9366 freq= 0.4993
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.04e+00
# x^[2 0]: 0.5030, x^[0 2]: 0.5201,
# r1:  0.2903,
# Forces Parameters:
# sin(x_0): amp= 1.9366 freq= 0.4993
#
# Set up skewed mass-spring system
# skewed parameter: 0.0005
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.50e-03
# x^[2 0]: 0.4978, x^[0 2]: 0.5006,
# r1:  0.2988,
# Forces Parameters:
# sin(x_0): amp= 1.9829 freq= 0.4994
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.01e+00
# x^[2 0]: 0.4741, x^[0 2]: 0.4881,
# r1:  0.2817,
# Forces Parameters:
# sin(x_0): amp= 1.9559 freq= 0.5123
#
# Set up skewed mass-spring system
# skewed parameter: 0.005
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.58e-03
# x^[2 0]: 0.4988, x^[0 2]: 0.5006,
# r1:  0.3025,
# Forces Parameters:
# sin(x_0): amp= 1.9849 freq= 0.5007
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.04e+00
# x^[2 0]: 0.4947, x^[0 2]: 0.5209,
# r1:  0.3074,
# Forces Parameters:
# sin(x_0): amp= 1.9312 freq= 0.5061
#
# Set up skewed mass-spring system
# skewed parameter: 0.05
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 1.37e-02
# x^[2 0]: 0.5057, x^[0 2]: 0.5016,
# r1:  0.3485,
# Forces Parameters:
# sin(x_0): amp= 1.9884 freq= 0.5006
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.02e+00
# x^[2 0]: 0.5117, x^[0 2]: 0.4773,
# r1:  0.3461,
# Forces Parameters:
# sin(x_0): amp= 1.9159 freq= 0.5147
#
# Set up skewed mass-spring system
# skewed parameter: 0.1
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.51e-03
# x^[2 0]: 0.4973, x^[1 1]: 0.1012, x^[0 2]: 0.4990,
# r1:  0.2977,
# Forces Parameters:
# sin(x_0): amp= 1.9822 freq= 0.5010
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.02e+00
# x^[2 0]: 0.4953, x^[1 1]: 0.0974, x^[0 2]: 0.5011,
# r1:  0.2871,
# Forces Parameters:
# sin(x_0): amp= 1.9397 freq= 0.4926
#
# Set up skewed mass-spring system
# skewed parameter: 0.01
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.79e-03
# x^[2 0]: 0.4993, x^[0 2]: 0.5014,
# r1:  0.3076,
# Forces Parameters:
# sin(x_0): amp= 1.9806 freq= 0.5004
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.03e+00
# x^[2 0]: 0.4750, x^[0 2]: 0.5001,
# r1:  0.3005,
# Forces Parameters:
# sin(x_0): amp= 1.9597 freq= 0.4998
#
# Set up skewed mass-spring system
# skewed parameter: 0.001
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.5e-03
# x^[2 0]: 0.4977, x^[0 2]: 0.5010,
# r1:  0.2993,
# Forces Parameters:
# sin(x_0): amp= 1.9808 freq= 0.5000
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.02e+00
# x^[2 0]: 0.4939, x^[0 2]: 0.5071,
# r1:  0.3014,
# Forces Parameters:
# sin(x_0): amp= 1.9466 freq= 0.4990
#
# Set up skewed mass-spring system
# skewed parameter: 0.0001
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.50e-03
# x^[2 0]: 0.4976, x^[0 2]: 0.5007,
# r1:  0.2980,
# Forces Parameters:
# sin(x_0): amp= 1.9807 freq= 0.4997
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.04e+00
# x^[2 0]: 0.4920, x^[0 2]: 0.5205,
# r1:  0.2838,
# Forces Parameters:
# sin(x_0): amp= 1.9171 freq= 0.5054

# %% [raw]
# ## With pruning_epsilon=1e-2
#
# Set up skewed mass-spring system
# skewed parameter: 0.07
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.51e-03
# x^[2 0]: 0.4975, x^[1 1]: 0.0717, x^[0 2]: 0.5012,
# r1:  0.2975,
# Forces Parameters:
# sin(x_0): amp= 1.9799 freq= 0.4999
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.03e+00
# x^[2 0]: 0.4900, x^[1 1]: 0.0485, x^[0 2]: 0.4997,
# r1:  0.2892,
# Forces Parameters:
# sin(x_0): amp= 1.9468 freq= 0.4894
#
# Set up skewed mass-spring system
# skewed parameter: 0.1
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.50e-03
# x^[2 0]: 0.4983, x^[1 1]: 0.1000, x^[0 2]: 0.4994,
# r1:  0.2973,
# Forces Parameters:
# sin(x_0): amp= 1.9815 freq= 0.4995
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.01e+00
# x^[2 0]: 0.4904, x^[1 1]: 0.1001, x^[0 2]: 0.4684,
# r1:  0.2751,
# Forces Parameters:
# sin(x_0): amp= 1.9340 freq= 0.5010
#
# Set up skewed mass-spring system
# skewed parameter: 0.05
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.52e-03
# x^[2 0]: 0.4969, x^[1 1]: 0.0501, x^[0 2]: 0.5003,
# r1:  0.2984,
# Forces Parameters:
# sin(x_0): amp= 1.9778 freq= 0.4993
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.03e+00
# x^[2 0]: 0.4829, x^[1 1]: 0.0515, x^[0 2]: 0.5082,
# r1:  0.2917,
# Forces Parameters:
# sin(x_0): amp= 1.9485 freq= 0.5117
#
# Set up skewed mass-spring system
# skewed parameter: 0.03
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.50e-03
# x^[2 0]: 0.4975, x^[1 1]: 0.0310, x^[0 2]: 0.4997,
# r1:  0.2979,
# Forces Parameters:
# sin(x_0): amp= 1.9770 freq= 0.5000
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.02e+00
# x^[2 0]: 0.4957, x^[1 1]: 0.0412, x^[0 2]: 0.5008,
# r1:  0.2994,
# Forces Parameters:
# sin(x_0): amp= 1.9173 freq= 0.4898
#
# Set up skewed mass-spring system
# skewed parameter: 0.01
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.8e-03
# x^[2 0]: 0.4996, x^[0 2]: 0.5006,
# r1:  0.3073,
# Forces Parameters:
# sin(x_0): amp= 1.9826 freq= 0.4991
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.04e+00
# x^[2 0]: 0.4978, x^[0 2]: 0.5000,
# r1:  0.3086,
# Forces Parameters:
# sin(x_0): amp= 1.9213 freq= 0.4785

# %% [raw]
# ## With pruning_epsilon=1e-3
#
# Set up skewed mass-spring system
# skewed parameter: 0.1
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.51e-03
# x^[2 0]: 0.4980, x^[1 1]: 0.1006, x^[0 2]: 0.5009,
# r1:  0.2977,
# Forces Parameters:
# sin(x_0): amp= 1.9818 freq= 0.4992
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.06e+00
# x^[1 0]:-0.0176, x^[2 0]: 0.4884, x^[3 0]: 0.0020, x^[2 1]: 0.0091, x^[1 1]: 0.0833,
# x^[1 2]:-0.0148, x^[0 1]:-0.0415, x^[0 2]: 0.5182, x^[0 3]:-0.0031,
# r1:  0.2639,
# Forces Parameters:
# sin(x_0): amp= 1.9079 freq= 0.5242
#
# Set up skewed mass-spring system
# skewed parameter: 0.07
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.50e-03
# x^[2 0]: 0.4987, x^[1 1]: 0.0711, x^[0 2]: 0.4995,
# r1:  0.2982,
# Forces Parameters:
# sin(x_0): amp= 1.9810 freq= 0.5005
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.02e+00
# x^[1 0]:-0.0203, x^[2 0]: 0.4832, x^[2 1]:-0.0092, x^[1 1]: 0.0754, x^[0 1]:-0.0282,
# x^[0 2]: 0.5109,
# r1:  0.2922,
# Forces Parameters:
# sin(x_0): amp= 1.9319 freq= 0.4948
#
# Set up skewed mass-spring system
# skewed parameter: 0.05
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.51e-03
# x^[2 0]: 0.4981, x^[1 1]: 0.0489, x^[0 2]: 0.4994,
# r1:  0.2978,
# Forces Parameters:
# sin(x_0): amp= 1.9817 freq= 0.4988
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.02e+00
# x^[1 0]: 0.0054, x^[2 0]: 0.4992, x^[2 1]: 0.0124, x^[1 1]: 0.0372, x^[0 1]:-0.0138,
# x^[0 2]: 0.5049,
# r1:  0.2749,
# Forces Parameters:
# sin(x_0): amp= 1.9279 freq= 0.4965
#
# Set up skewed mass-spring system
# skewed parameter: 0.03
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.51e-03
# x^[2 0]: 0.4978, x^[1 1]: 0.0301, x^[0 2]: 0.5004,
# r1:  0.2983,
# Forces Parameters:
# sin(x_0): amp= 1.9828 freq= 0.4999
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.06e+00
# x^[1 0]:-0.0361, x^[2 0]: 0.4798, x^[3 0]:-0.0163, x^[1 1]: 0.0399, x^[1 2]:-0.0151,
# x^[0 1]: 0.0230, x^[0 2]: 0.4730,
# r1:  0.2903,
# Forces Parameters:
# sin(x_0): amp= 1.9206 freq= 0.5044
#
# Set up skewed mass-spring system
# skewed parameter: 0.01
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.51e-03
# x^[2 0]: 0.4990, x^[1 1]: 0.0102, x^[0 2]: 0.5002,
# r1:  0.2981,
# Forces Parameters:
# sin(x_0): amp= 1.9842 freq= 0.4995
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.05e+00
# x^[1 0]: 0.0164, x^[2 0]: 0.4732, x^[2 1]: 0.0011, x^[1 1]: 0.0034, x^[1 2]:-0.0121,
# x^[0 2]: 0.4979, x^[0 3]:-0.0012,
# r1:  0.2904,
# Forces Parameters:
# sin(x_0): amp= 1.9457 freq= 0.5010
#
# Set up skewed mass-spring system
# skewed parameter: 0.007
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.50e-03
# x^[2 0]: 0.4979, x^[1 1]: 0.0051, x^[0 2]: 0.4999,
# r1:  0.2977,
# Forces Parameters:
# sin(x_0): amp= 1.9821 freq= 0.5000
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.05e+00
# x^[1 0]:-0.0164, x^[2 0]: 0.4914, x^[3 0]: 0.0073, x^[1 1]: 0.0093, x^[1 2]:-0.0170,
# x^[0 2]: 0.5161,
# r1:  0.2912,
# Forces Parameters:
# sin(x_0): amp= 1.9269 freq= 0.5022
#
# Set up skewed mass-spring system
# skewed parameter: 0.005
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.59e-03
# x^[2 0]: 0.4975, x^[0 2]: 0.5020,
# r1:  0.3028,
# Forces Parameters:
# sin(x_0): amp= 1.9780 freq= 0.5004
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.04e+00
# x^[2 0]: 0.4969, x^[0 2]: 0.5114,
# r1:  0.2871,
# Forces Parameters:
# sin(x_0): amp= 1.9290 freq= 0.4945
#
# Set up skewed mass-spring system
# skewed parameter: 0.003
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.51e-03
# x^[2 0]: 0.4987, x^[1 1]: 0.0028, x^[0 2]: 0.5004,
# r1:  0.2978,
# Forces Parameters:
# sin(x_0): amp= 1.9767 freq= 0.4993
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.05e+00
# x^[1 0]: 0.0012, x^[2 0]: 0.4845, x^[1 1]:-0.0196, x^[0 1]:-0.0098, x^[0 2]: 0.5075,
# x^[0 3]: 0.0044,
# r1:  0.2709,
# Forces Parameters:
# sin(x_0): amp= 1.9334 freq= 0.4951
#
# Set up skewed mass-spring system
# skewed parameter: 0.001
# noise_std: 0.2
# Train PHSI model
# Finished training after epoch 149
# Training loss: 6.50e-03
# x^[2 0]: 0.4992, x^[0 2]: 0.4990,
# r1:  0.2989,
# Forces Parameters:
# sin(x_0): amp= 1.9838 freq= 0.5000
#
# Train PHSI model on noisy data
# Finished training after epoch 149
# Training loss: 8.07e+00
# x^[2 0]: 0.4874, x^[3 0]: 0.0021, x^[2 1]: 0.0039, x^[1 1]:-0.0062, x^[1 2]:-0.0053,
# x^[0 2]: 0.5280, x^[0 3]: 0.0133,
# r1:  0.2988,
# Forces Parameters:
# sin(x_0): amp= 1.9316 freq= 0.5024
